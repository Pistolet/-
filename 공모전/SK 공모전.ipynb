# %% [markdown]
# **시간대유동**
# --------------

# %%
import pandas as pd 
import numpy as np 
import matplotlib 
import matplotlib.pyplot as plt


time_sk = pd.read_csv("D:\\data\\통신\\시간대유동\\강남3구_시간대유동인구_201601.CSV",sep='|',engine='python')
time_sk.head()
# Out:
#    STD_YM  구코드  법정동코드      X_COORD  Y_COORD  TMST_00  TMST_01  TMST_02  \
# 0  201601   65    108  957052.8750  1943841    21.49    12.70     7.79
# 1  201601   65    108  957052.6875  1943790    15.70     9.49     5.88
# 2  201601   65    108  957150.6250  1943738     3.24     1.64     0.94
# 3  201601   65    108  957150.3750  1943686    15.17     9.75     6.42
# 4  201601   65    108  957101.1875  1943687    11.77     8.01     5.43
#
#    TMST_03  TMST_04   ...     TMST_14  TMST_15  TMST_16  TMST_17  TMST_18  \
# 0     4.59     2.89   ...      192.92   189.23   184.63   180.35   170.22
# 1     3.69     2.35   ...      126.87   125.11   122.47   118.85   110.33
# 2     0.52     0.39   ...       21.11    21.24    21.58    21.18    19.62
# 3     4.08     2.57   ...       79.21    80.35    80.28    79.83    79.43
# 4     3.56     2.22   ...       55.60    56.07    55.56    55.56    55.99
#
#    TMST_19  TMST_20  TMST_21  TMST_22  TMST_23
# ...

# %% [markdown]
# **데이터 형상**

# %%
time_sk.shape
# Out:
# (30088, 29)

# %% [markdown]
# **필요 컬럼추출** (x,y 좌표와 시간대)

# %%
time_sk2=time_sk[['X_COORD','Y_COORD','TMST_00','TMST_01','TMST_02','TMST_03','TMST_04','TMST_14','TMST_15','TMST_16','TMST_17','TMST_18','TMST_19','TMST_20','TMST_21','TMST_22','TMST_23']]
time_sk2.head()
#print(time_sk2.columns)
#print(time_sk2.shape)
# Out:
#        X_COORD  Y_COORD  TMST_00  TMST_01  TMST_02  TMST_03  TMST_04  TMST_14  \
# 0  957052.8750  1943841    21.49    12.70     7.79     4.59     2.89   192.92
# 1  957052.6875  1943790    15.70     9.49     5.88     3.69     2.35   126.87
# 2  957150.6250  1943738     3.24     1.64     0.94     0.52     0.39    21.11
# 3  957150.3750  1943686    15.17     9.75     6.42     4.08     2.57    79.21
# 4  957101.1875  1943687    11.77     8.01     5.43     3.56     2.22    55.60
#
#    TMST_15  TMST_16  TMST_17  TMST_18  TMST_19  TMST_20  TMST_21  TMST_22  \
# 0   189.23   184.63   180.35   170.22   112.81    82.89    72.19    58.15
# 1   125.11   122.47   118.85   110.33    73.42    55.63    48.67    38.82
# 2    21.24    21.58    21.18    19.62    15.03    12.08    10.57     8.66
# 3    80.35    80.28    79.83    79.43    59.80    46.07    41.38    33.55
# 4    56.07    55.56    55.56    55.99    42.22    32.67    29.42    24.08
#
#    TMST_23
# 0    35.66
# 1    25.36
# 2     5.45
# ...

# %% [markdown]
# **데이터 시각화(시간에 따른 지역 분포경향, Y_COORD를 중심으로)**

# %%
time_sk2.plot("Y_COORD",'TMST_00')
time_sk2.plot("Y_COORD",'TMST_01')
time_sk2.plot("Y_COORD",'TMST_02')
time_sk2.plot("Y_COORD",'TMST_03')
time_sk2.plot("Y_COORD",'TMST_04')
time_sk2.plot("Y_COORD",'TMST_14')
time_sk2.plot("Y_COORD",'TMST_15')
time_sk2.plot("Y_COORD",'TMST_16')
time_sk2.plot("Y_COORD",'TMST_17')
time_sk2.plot("Y_COORD",'TMST_18')
time_sk2.plot("Y_COORD",'TMST_19')
time_sk2.plot("Y_COORD",'TMST_20')
time_sk2.plot("Y_COORD",'TMST_21')
time_sk2.plot("Y_COORD",'TMST_22')
time_sk2.plot("Y_COORD",'TMST_23')

# %% [markdown]
# **데이터 시각화(시간에 따른 지역 분포경향, X_COORD를 중심으로)**

# %%
time_sk2.plot("X_COORD",'TMST_00',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_01',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_02',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_03',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_04',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_14',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_15',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_16',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_17',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_18',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_19',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_20',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_21',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_22',COLOR='GREEN')
time_sk2.plot("X_COORD",'TMST_23',COLOR='GREEN')

# %% [markdown]
# **요일별유동**
# --------------

# %%
day_sk = pd.read_csv("D:\\data\\통신\\요일별유동\\강남3구_요일별유동인구_201601.CSV",sep='|',engine='python')
day_sk.head()
# Out:
#    STD_YM  구코드  법정동코드      X_COORD  Y_COORD  FLOW_POP_CNT_MON  \
# 0  201601   65    108  957052.6875  1943790           1876.56
# 1  201601   65    108  957052.8750  1943841           2823.08
# 2  201601   65    108  957150.6250  1943738            327.22
# 3  201601   65    108  957150.3750  1943686           1250.12
# 4  201601   65    108  957101.1875  1943687            887.58
#
#    FLOW_POP_CNT_TUS  FLOW_POP_CNT_WED  FLOW_POP_CNT_THU  FLOW_POP_CNT_FRI  \
# 0           1882.91           1900.25           1931.12           1640.16
# 1           2835.25           2871.04           2922.21           2454.86
# 2            327.21            323.93            320.74            293.40
# 3           1259.40           1282.71           1290.37           1137.42
# 4            897.77            910.94            933.26            813.61
#
#    FLOW_POP_CNT_SAT  FLOW_POP_CNT_SUN
# 0            772.53            483.70
# 1           1085.63            605.55
# ...

# %% [markdown]
# **데이터 형상**

# %%
day_sk.shape
# Out:
# (30088, 12)

# %% [markdown]
# **필요 컬럼추출(x,y 좌표와 요일)**

# %%
day_sk2=day_sk[['X_COORD','Y_COORD','FLOW_POP_CNT_MON','FLOW_POP_CNT_TUS','FLOW_POP_CNT_WED','FLOW_POP_CNT_THU','FLOW_POP_CNT_FRI','FLOW_POP_CNT_SAT','FLOW_POP_CNT_SUN']]
day_sk2.head()
# Out:
#        X_COORD  Y_COORD  FLOW_POP_CNT_MON  FLOW_POP_CNT_TUS  FLOW_POP_CNT_WED  \
# 0  957052.6875  1943790           1876.56           1882.91           1900.25
# 1  957052.8750  1943841           2823.08           2835.25           2871.04
# 2  957150.6250  1943738            327.22            327.21            323.93
# 3  957150.3750  1943686           1250.12           1259.40           1282.71
# 4  957101.1875  1943687            887.58            897.77            910.94
#
#    FLOW_POP_CNT_THU  FLOW_POP_CNT_FRI  FLOW_POP_CNT_SAT  FLOW_POP_CNT_SUN
# 0           1931.12           1640.16            772.53            483.70
# 1           2922.21           2454.86           1085.63            605.55
# 2            320.74            293.40            195.60            144.98
# 3           1290.37           1137.42            652.11            423.57
# 4            933.26            813.61            433.68            273.96

# %% [markdown]
# **데이터 시각화(요일에 따른 지역 분포경향, Y_COORD를 중심으로)**

# %%
day_sk2.plot('Y_COORD','FLOW_POP_CNT_MON')
day_sk2.plot('Y_COORD','FLOW_POP_CNT_TUS')
day_sk2.plot('Y_COORD','FLOW_POP_CNT_WED')
day_sk2.plot('Y_COORD','FLOW_POP_CNT_THU')
day_sk2.plot('Y_COORD','FLOW_POP_CNT_FRI')
day_sk2.plot('Y_COORD','FLOW_POP_CNT_SAT')
day_sk2.plot('Y_COORD','FLOW_POP_CNT_SUN')

# %% [markdown]
# **데이터 시각화(요일에 따른 지역 분포경향, X_COORD를 중심으로)**

# %%
day_sk2.plot('X_COORD','FLOW_POP_CNT_MON')
day_sk2.plot('X_COORD','FLOW_POP_CNT_TUS')
day_sk2.plot('X_COORD','FLOW_POP_CNT_WED')
day_sk2.plot('X_COORD','FLOW_POP_CNT_THU')
day_sk2.plot('X_COORD','FLOW_POP_CNT_FRI')
day_sk2.plot('X_COORD','FLOW_POP_CNT_SAT')
day_sk2.plot('X_COORD','FLOW_POP_CNT_SUN')

# %% [markdown]
# **성연령유동**
# --------------

# %%
sex_sk = pd.read_csv("D:\\data\\통신\\성연령유동\\강남3구_성연령유동인구_201601.CSV",sep='|',engine='python')
sex_sk.head()
# Out:
#    STD_YM  구코드  법정동코드      X_COORD  Y_COORD  MAN_FLOW_POP_CNT_10G  \
# 0  201601   65    108  957052.8750  1943841                 27.46
# 1  201601   65    108  957052.6875  1943790                 18.73
# 2  201601   65    108  957150.6250  1943738                  8.61
# 3  201601   65    108  957150.3750  1943686                 18.46
# 4  201601   65    108  957101.1875  1943687                 10.18
#
#    MAN_FLOW_POP_CNT_20G  MAN_FLOW_POP_CNT_30G  MAN_FLOW_POP_CNT_40G  \
# 0                105.89                289.85                395.16
# 1                 70.92                197.39                260.30
# 2                 15.35                 26.83                 32.57
# 3                 66.26                148.73                151.83
# 4                 47.02                113.97                116.00
#
#    MAN_FLOW_POP_CNT_50G  MAN_FLOW_POP_CNT_60GU  WMAN_FLOW_POP_CNT_10G  \
# 0                304.55                 217.39                  22.19
# ...

# %% [markdown]
# **데이터 형상**

# %%
sex_sk.shape
# Out:
# (30088, 17)

# %% [markdown]
# **필요 컬럼추출 (x,y 좌표와 성연령)**

# %%
sex_sk2=sex_sk[['X_COORD','Y_COORD','MAN_FLOW_POP_CNT_10G','MAN_FLOW_POP_CNT_20G','MAN_FLOW_POP_CNT_30G','MAN_FLOW_POP_CNT_40G','MAN_FLOW_POP_CNT_50G','MAN_FLOW_POP_CNT_60GU','WMAN_FLOW_POP_CNT_10G','WMAN_FLOW_POP_CNT_20G','WMAN_FLOW_POP_CNT_30G','WMAN_FLOW_POP_CNT_40G','WMAN_FLOW_POP_CNT_50G','WMAN_FLOW_POP_CNT_60GU']]
sex_sk2.head()
# Out:
#        X_COORD  Y_COORD  MAN_FLOW_POP_CNT_10G  MAN_FLOW_POP_CNT_20G  \
# 0  957052.8750  1943841                 27.46                105.89
# 1  957052.6875  1943790                 18.73                 70.92
# 2  957150.6250  1943738                  8.61                 15.35
# 3  957150.3750  1943686                 18.46                 66.26
# 4  957101.1875  1943687                 10.18                 47.02
#
#    MAN_FLOW_POP_CNT_30G  MAN_FLOW_POP_CNT_40G  MAN_FLOW_POP_CNT_50G  \
# 0                289.85                395.16                304.55
# 1                197.39                260.30                195.91
# 2                 26.83                 32.57                 26.13
# 3                148.73                151.83                111.97
# 4                113.97                116.00                 84.63
#
#    MAN_FLOW_POP_CNT_60GU  WMAN_FLOW_POP_CNT_10G  WMAN_FLOW_POP_CNT_20G  \
# 0                 217.39                  22.19                 131.76
# ...

# %% [markdown]
# **데이터 시각화(성연령에 따른 지역 분포경향, Y_COORD를 중심으로)**

# %%
sex_sk2.plot('Y_COORD','MAN_FLOW_POP_CNT_10G')
sex_sk2.plot('Y_COORD','MAN_FLOW_POP_CNT_20G')
sex_sk2.plot('Y_COORD','MAN_FLOW_POP_CNT_30G')
sex_sk2.plot('Y_COORD','MAN_FLOW_POP_CNT_40G')
sex_sk2.plot('Y_COORD','MAN_FLOW_POP_CNT_50G')
sex_sk2.plot('Y_COORD','MAN_FLOW_POP_CNT_60GU')
sex_sk2.plot('Y_COORD','WMAN_FLOW_POP_CNT_10G',COLOR="VIOLET")
sex_sk2.plot('Y_COORD','WMAN_FLOW_POP_CNT_20G',COLOR="VIOLET")
sex_sk2.plot('Y_COORD','WMAN_FLOW_POP_CNT_30G',COLOR="VIOLET")
sex_sk2.plot('Y_COORD','WMAN_FLOW_POP_CNT_40G',COLOR="VIOLET")
sex_sk2.plot('Y_COORD','WMAN_FLOW_POP_CNT_50G',COLOR="VIOLET")
sex_sk2.plot('Y_COORD','WMAN_FLOW_POP_CNT_60GU',COLOR="VIOLET")

# %% [markdown]
# **데이터 시각화(성연령에 따른 지역 분포경향, X_COORD를 중심으로)**

# %%
sex_sk2.plot('X_COORD','MAN_FLOW_POP_CNT_10G')
sex_sk2.plot('X_COORD','MAN_FLOW_POP_CNT_20G')
sex_sk2.plot('X_COORD','MAN_FLOW_POP_CNT_30G')
sex_sk2.plot('X_COORD','MAN_FLOW_POP_CNT_40G')
sex_sk2.plot('X_COORD','MAN_FLOW_POP_CNT_50G')
sex_sk2.plot('X_COORD','MAN_FLOW_POP_CNT_60GU')
sex_sk2.plot('X_COORD','WMAN_FLOW_POP_CNT_10G',COLOR="VIOLET")
sex_sk2.plot('X_COORD','WMAN_FLOW_POP_CNT_20G',COLOR="VIOLET")
sex_sk2.plot('X_COORD','WMAN_FLOW_POP_CNT_30G',COLOR="VIOLET")
sex_sk2.plot('X_COORD','WMAN_FLOW_POP_CNT_40G',COLOR="VIOLET")
sex_sk2.plot('X_COORD','WMAN_FLOW_POP_CNT_50G',COLOR="VIOLET")
sex_sk2.plot('X_COORD','WMAN_FLOW_POP_CNT_60GU',COLOR="VIOLET")

# %% [markdown]
# **신한카드 요일별 사용**
# ------------------------

# %%
day_sh = pd.read_csv("D:\\data\\통신\\신한카드\\DAY_CARD_SPENDING.csv",sep='|',engine='python')
day_sh.head()
# Out:
#    STD_YM  GU_CD DONG_CD  MCT_CAT_CD  DAY_CD  USE_CNT   USE_AMT
# 0  201601     65     101           1       1      914  37910721
# 1  201601     65     101           1       2      343  12191094
# 2  201601     65     101           1       3      400  16122078
# 3  201601     65     101           1       4      426  19893142
# 4  201601     65     101           1       5      489  19934581

# %% [markdown]
# **데이터 형상**

# %%
day_sh.shape
# Out:
# (86163, 7)

# %% [markdown]
# **필요 컬럼추출(업종코드, 이용건수)-1**

# %%
day_sh2=day_sh[['MCT_CAT_CD','USE_CNT']]
day_sh2.head()
# Out:
#    MCT_CAT_CD  USE_CNT
# 0           1      914
# 1           1      343
# 2           1      400
# 3           1      426
# 4           1      489

# %% [markdown]
# **데이터 시각화(업종에 따른 이용건수)**

# %%
day_sh2.plot('MCT_CAT_CD','USE_CNT')

# %% [markdown]
# **필요 컬럼추출(업종코드, 이용금액)-2**

# %%
day_sh3=day_sh[['MCT_CAT_CD','USE_AMT']]
day_sh3.head()
# Out:
#    MCT_CAT_CD   USE_AMT
# 0           1  37910721
# 1           1  12191094
# 2           1  16122078
# 3           1  19893142
# 4           1  19934581

# %% [markdown]
# **데이터 시각화(업종에 따른 이용금액)**

# %%
day_sh3.plot('MCT_CAT_CD','USE_AMT')

# %% [markdown]
# **데이터 시각화(업소에 따른 이용금액)**

# %% [markdown]
# **필요 컬럼추출(요일코드, 이용건수)-1**

# %%
day_sh4=day_sh[['DAY_CD','USE_CNT']]
day_sh4.head()
# Out:
#    DAY_CD  USE_CNT
# 0       1      914
# 1       2      343
# 2       3      400
# 3       4      426
# 4       5      489

# %% [markdown]
# **데이터 시각화(요일에 따른 이용건수)**

# %%
day_sh4.plot('DAY_CD','USE_CNT')

# %% [markdown]
# **필요 컬럼추출(요일코드, 이용금액)-2**

# %%
day_sh5=day_sh[['DAY_CD','USE_AMT']]
day_sh5.head()
# Out:
#    DAY_CD   USE_AMT
# 0       1  37910721
# 1       2  12191094
# 2       3  16122078
# 3       4  19893142
# 4       5  19934581

# %%
day_sh5.plot('DAY_CD','USE_AMT')
